# %%
import requests

headers = {
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Referer': 'https://www.lagou.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,zh-TW;q=0.7',
}

params = (
    ('labelWords', ''),
    ('fromSearch', 'true'),
    ('suginput', ''),
)
s = requests.Session()
s.headers.update(headers)

response = s.get('https://www.lagou.com/jobs/list_python', params=params)
print(response)
data = {
    'first': 'true',
    'pn': '1',
    'kd': 'python'
}

r = s.post('https://www.lagou.com/jobs/positionAjax.json?needAddtionalResult=false', data=data, headers={
    'Origin': 'https://www.lagou.com',
    'X-Anit-Forge-Code': '0',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Referer': 'https://www.lagou.com/jobs/list_python?labelWords=&fromSearch=true&suginput=',
    'X-Requested-With': 'XMLHttpRequest',
    'X-Anit-Forge-Token': 'None',
})
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'requestId': None,
#  'msg': None,
#  'resubmitToken': None,
#  'success': True,
#  'code': 0,
#  'content': {'hrInfoMap': {'6042236': {'userId': 11315020,
#     'userLevel': 'G1',
#     'positionName': '招聘者',
#     'portrait': 'i/image2/M01/B9/AA/CgoB5lwXRa-AFo-gAABcJh6-fIk49.jpeg',
#     'phone': None,
#     'receiveEmail': None,
#     'canTalk': True,
#     'realName': 'Elle.L'},
#    '5354513': {'userId': 11119610,
#     'userLevel': 'G1',
#     'positionName': '人事专员',
#     'portrait': 'i/image2/M01/6B/CD/CgotOVtNl1aAJ7lGAAD6W-eST9g850.jpg',
#     'phone': None,
#     'receiveEmail': None,
#     'canTalk': True,
#     'realName': '杜杜'},
#    '5924120': {'userId': 4104967,
#     'userLevel': 'G1',
#     'positionName': '',
#     'portrait': 'i/image2/M01/44/BB/CgotOVz_IaqAG_wYAAAp9X23zrs96.jpeg',
#     'phone': None,
#     'receiveEmail': None,
#     'canTalk': True,
#     'realName': 'HR'},
#    '4813869': {'userId': 11092542,
#     'userLevel': 'G1',
# ...

# %%
datas = r.json()['content']['positionResult']['result']

# %%
datas
# Out:
# [{'companyId': 393510,
#   'longitude': '116.48233',
#   'latitude': '39.997316',
#   'hitags': None,
#   'resumeProcessRate': 80,
#   'resumeProcessDay': 1,
#   'imState': 'threeDays',
#   'lastLogin': 1560498248000,
#   'explain': None,
#   'plus': None,
#   'pcShow': 0,
#   'appShow': 0,
#   'deliver': 0,
#   'gradeDescription': None,
#   'promotionScoreExplain': None,
#   'firstType': '开发|测试|运维类',
#   'secondType': '后端开发',
#   'isSchoolJob': 0,
#   'subwayline': '15号线',
#   'stationname': '望京东',
#   'linestaion': '14号线东段_望京;14号线东段_阜通;14号线东段_望京南;15号线_望京东;15号线_望京',
#   'thirdType': 'Python',
#   'skillLables': ['后端', 'Python'],
#   'isHotHire': 0,
#   'positionName': '高级python开发工程师',
#   'workYear': '3-5年',
#   'education': '本科',
#   'jobNature': '全职',
#   'formatCreateTime': '1天前发布',
#   'positionId': 5508882,
#   'city': '北京',
#   'createTime': '2019-06-14 12:26:44',
#   'companyLogo': 'i/image2/M01/19/84/CgotOVyxjp2AADr5AAIWoBHmdVw796.png',
#   'industryField': '移动互联网',
# ...

# %%
import pandas as pd

# %%
import pprint
ls = []
for item in datas:
    companyId =item['companyId']
    companyFullName=item['companyFullName']
    workYear=item['workYear']
    education=item['education']
    salary=item['salary']
    vpositionId=item['positionId']
    
    ls.append([companyId,companyFullName,workYear,education,salary,vpositionId])
pprint.pprint(ls)
# Out:
# [[393510, '北京右划网络科技有限公司', '3-5年', '本科', '25k-50k', 5508882],
#  [133920, '北京小度互娱科技有限公司', '1-3年', '本科', '15k-25k', 4990844],
#  [141699, '开易（北京）科技有限公司', '不限', '本科', '10k-18k', 5924120],
#  [28121, '深圳市客路网络科技有限公司', '1-3年', '本科', '10k-20k', 5959430],
#  [19209, '广州回头车信息科技有限公司', '1-3年', '大专', '10k-15k', 6046368],
#  [158669, '行云智能（深圳）技术有限公司', '1-3年', '本科', '10k-20k', 4147727],
#  [16831, '武汉佰钧成技术有限责任公司', '3-5年', '本科', '12k-20k', 6048143],
#  [491975, '卓尔智联集团有限公司', '1-3年', '本科', '6k-12k', 6047395],
#  [149130, '广州西洋汇信息技术有限公司', '3-5年', '本科', '10k-20k', 6046727],
#  [26467, '上海思华科技股份有限公司', '3-5年', '本科', '18K-35K', 2761567],
#  [407314, '上海吸引子信息科技有限公司', '不限', '本科', '10k-20k', 4813869],
#  [420697, '四川喵星城科技有限公司', '3-5年', '本科', '10k-20k', 6025094],
#  [93808, '北京汇游科技有限公司', '3-5年', '本科', '15k-20k', 5946526],
#  [8861, '北京汇行科技有限公司', '3-5年', '不限', '15k-25k', 6042236],
#  [84515, '钱咖网络科技（上海）有限公司', '3-5年', '本科', '15k-30k', 5354513]]

# %%
#搞個標題杯
df =pd.DataFrame(ls,columns=['companyId','companyFullName','workYear','education','salary','vpositionId'])
df
# Out:
#     companyId companyFullName workYear education   salary  vpositionId
# 0      393510    北京右划网络科技有限公司     3-5年        本科  25k-50k      5508882
# 1      133920    北京小度互娱科技有限公司     1-3年        本科  15k-25k      4990844
# 2      141699    开易（北京）科技有限公司       不限        本科  10k-18k      5924120
# 3       28121   深圳市客路网络科技有限公司     1-3年        本科  10k-20k      5959430
# 4       19209   广州回头车信息科技有限公司     1-3年        大专  10k-15k      6046368
# 5      158669  行云智能（深圳）技术有限公司     1-3年        本科  10k-20k      4147727
# 6       16831   武汉佰钧成技术有限责任公司     3-5年        本科  12k-20k      6048143
# 7      491975      卓尔智联集团有限公司     1-3年        本科   6k-12k      6047395
# 8      149130   广州西洋汇信息技术有限公司     3-5年        本科  10k-20k      6046727
# 9       26467    上海思华科技股份有限公司     3-5年        本科  18K-35K      2761567
# 10     407314   上海吸引子信息科技有限公司       不限        本科  10k-20k      4813869
# 11     420697     四川喵星城科技有限公司     3-5年        本科  10k-20k      6025094
# ...
